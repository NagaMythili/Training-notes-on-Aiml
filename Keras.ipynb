# %% [markdown]
# # ----------------------------------------KERAS------------------------------------------

# %% [markdown]
# ![kera.jpg](attachment:kera.jpg)

# %% [markdown]
# ![feaker.jpg](attachment:feaker.jpg)

# %% [markdown]
# # SAMPLE CODE OF CNN :

# %% [markdown]
# This code represents a simple convolutional neural network (CNN) built using TensorFlow's Keras API to classify handwritten digits from the MNIST dataset.

# %%
import tensorflow as tf
from tensorflow.keras import layers,models
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist          #no.of input stmts

#load and preproces the MNISt dataset
(train_images,train_labels),(test_images,test_labels)=mnist.load_data()
train_images=train_images.reshape((60000,28,28,1)).astype('float32')/255
test_images=test_images.reshape((10000,28,28,1)).astype('float32')/255
train_labels=to_categorical(train_labels)
test_labels=to_categorical(test_labels)
#build a simple convolutional neural network using keras
model=models.Sequential()
model.add(layers.Conv2D(32,(3,3),activation='relu',input_shape=(28,28,1)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(3,3),activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Dense(64,activation='relu'))
model.add(layers.Dense(10,activation='softmax'))
#compile the model
model.compile(optimizer='adam',#to optimize the loss of data
              loss='categorical_crossentropy',#crossentropy is used to work on n number of functions at a time
              metrics=['accuray'])
#Train the model
model.fit(train_images,train_labels,epochs=5,batch_size=64,
          validation_split=0.2)
#Evaluate the model on the test set
test_loss,test_acc=model.evaluate(test_images,test_labels)
print(f'testaccuracy:{test_acc}')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-82438f2a9a9e> in <module>
# ----> 1 import tensorflow as tf
#       2 from tensorflow.keras import layers,models
#       3 from tensorflow.keras.utils import to_categorical
#       4 from tensorflow.keras.datasets import mnist          #no.of input stmts
#       5
#
# ModuleNotFoundError: No module named 'tensorflow'

# %% [markdown]
# here it is unable to run we need to install all requirements ...so done this in vs code as shown below

# %% [markdown]
# ![cnn%20si.jpg](attachment:cnn%20si.jpg)

# %% [raw]
# Data Loading and Preprocessing:
#
# The code starts by importing necessary TensorFlow modules and datasets.
# It loads the MNIST dataset using mnist.load_data() and preprocesses it by reshaping the images to the required format (28x28 pixels with one color channel) and scaling pixel values to a range of 0 to 1.
#
# Model Architecture:
#
# The model is constructed using the Sequential API from Keras.
# It consists of:
# Two convolutional layers (Conv2D) with ReLU activation followed by max-pooling layers (MaxPooling2D). These layers help the network learn hierarchical features from the images.
# A Flatten layer to convert the 2D output into a 1D vector.
# Two dense layers (Dense) with ReLU activation. The last dense layer uses the softmax activation function to output probabilities for each class (digits 0 to 9).
# The model architecture helps extract features from images and make predictions.
#
# Model Compilation:
#
# The model is compiled using model.compile() where:
# Optimizer: 'adam' is used, an adaptive learning rate optimization algorithm.
# Loss function: 'categorical_crossentropy' is used as the loss function, suitable for multiclass classification problems.
# Metrics: 'accuracy' is selected to monitor the accuracy of the model during training.
#
# Model Training:
#
# The model is trained using model.fit() on the preprocessed training data for 5 epochs with a batch size of 64. Validation data of 20% of the training set is used to monitor the model's performance during training.
#
# Model Evaluation:
#
# After training, the model's performance is evaluated using the test set (test_images, test_labels) using model.evaluate().
# The test accuracy is printed out to assess how well the model performs on unseen data.
# This code overall creates, trains, and evaluates a CNN for classifying handwritten digits from the MNIST dataset, aiming to achieve high accuracy in identifying the correct digit from its image.

# %% [markdown]
# # SAMPLE CODE CNN 2 :
