# %% [markdown]
# # -------------------------------------------------GEN AI-------------------------------------------

# %% [markdown]
# ![gnai.jpg](attachment:gnai.jpg)

# %% [markdown]
# ![genai2.jpg](attachment:genai2.jpg)

# %% [markdown]
# ![gen%203.jpg](attachment:gen%203.jpg)

# %% [markdown]
# ![gen%204.jpg](attachment:gen%204.jpg)

# %% [markdown]
# ![gen5.jpg](attachment:gen5.jpg)

# %% [markdown]
# ![gen6.jpg](attachment:gen6.jpg)
